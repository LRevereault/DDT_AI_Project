# %% [markdown]
# # Links to BigML queries

# %% [markdown]
# ##Datasets
# Dataset - all\
# https://bigml.com/shared/dataset/d5EGmChwRYAwMZd0p5q64uLJX8o \
#
# Dataset – cluster 4 \
# https://bigml.com/shared/dataset/eVnK8VPMJyWQsNozARXv0nt13ef \
#
# Dataset – cluster 6 \
# https://bigml.com/shared/dataset/xbmCdLwYW6I3168vlPLoNmrdwGp \
#
# Dataset – cluster 7 \
# https://bigml.com/shared/dataset/5iDkFqdcj3R9YpDnig9Xcedh67e

# %% [markdown]
# ##Clustering model
# https://bigml.com/shared/cluster/58gDtPX8jOYyb3XZkrtrxpYvUjA

# %% [markdown]
# ##Tree Clusters
# DCT model – cluster 4 \
# https://bigml.com/shared/model/nNV7htxTAlpAA1L2M1XmoalTQn4 \
#
# DCT model – cluster 6 \
# https://bigml.com/shared/model/1dneRtYnTCaCWByovNMqbc4SGOe \
#
# DCT model – cluster 7 \
# https://bigml.com/shared/model/pVBicUdQxihzPDyCSsV2I1NN7Ej \
